# %%
import torch
import torchviz
import sys
sys.path.append('../src')

# %%
def calc_loss(z):
    return z ** 2

# %%
from torch.distributions import Normal
mu, sigma = torch.tensor([0.0], requires_grad=True), torch.tensor([1.0], requires_grad=True)
m = Normal(mu, sigma)

try:
    z = m.sample()
    loss = calc_loss(z)
    loss.backward()
except:
    print('Backpropogation error for sample')
    z = m.rsample()
    print('z = ', z.item())
    loss = calc_loss(z)
    loss.backward()

torchviz.make_dot(loss,  params = {'mu': mu, 'sigma': sigma} )
# Out:
# Backpropogation error for sample
# z =  -0.5397640466690063

# %%
import irt
import irt.distributions
import torch

mu, sigma = torch.tensor([0.0], requires_grad=True), torch.tensor([1.0], requires_grad=True)
m = irt.distributions.Normal(mu, sigma)

try:
    z = m.sample()
    loss = calc_loss(z)
    loss.backward()
except:
    print('Backpropogation error for sample')
    z = m.rsample()
    print('z = ', z.item())
    loss = calc_loss(z)
    loss.backward()

# mu.grad, sigma.grad
print(mu.grad, sigma.grad)
torchviz.make_dot(loss,  params = {'mu': mu, 'sigma': sigma} )
# Out:
# Backpropogation error for sample
# z =  -0.526225745677948
# tensor([-1.0525]) tensor([0.5538])
